# %% [markdown]
# <a href="https://colab.research.google.com/github/astikarganesh/25-26-4093-Ganesh-AI-B-DS/blob/main/28april.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import Lasso
x=np.array([[1,25,160],[2,30,165],[3,35,170]])
y=np.array([3000,4000,5000])
model=Lasso(alpha=0.1)
model.fit(x,y)
print(model.coef_)
# Out:
# [8.79970000e+02 2.40000000e+01 4.52970994e-16]
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.112e+02, tolerance: 2.000e+02
#   model = cd_fast.enet_coordinate_descent(

# %%
import numpy as np
from sklearn.linear_model import Lasso
x=np.array([[1,5,2],[2,6,4],[3,7,6],[4,8,8]])
y=np.array([5,10,15,20])
model=Lasso(alpha=0.1)
model.fit(x,y)
print("coefficent",model.coef_)
# Out:
# coefficent [0.   0.   2.48]

# %%
import numpy as np
from scipy.spatial import distance
from scipy.stats import pearsonr
point1=np.array([2,3])
point2=np.array([5,7])
eucliden=distance.euclidean(point1,point1)
manhattan=distance.cityblock(point1,point2)
chebyshev=distance.chebyshev(point1,point2)
hamming=distance.hamming(point1,point2)
cosine_distance=distance.cosine(point1,point2)
cosine_similarity=1-cosine_distance
set1,set2=set(point1),set(point2)
jaccard_similarity=len(set1&set2)/len(set1|set2)
r=pearsonr(point1,point2)
print("eucliden distance",eucliden)
print("manhattan distance",manhattan)
print("chebyshev distance",chebyshev)
print("hamming distance:" ,hamming)
print("jaccard similarity:" ,jaccard_similarity)
print("prasonr correlation:", r)
# Out:
# eucliden distance 0.0
# manhattan distance 7
# chebyshev distance 4
# hamming distance: 1.0
# jaccard similarity: 0.0
# prasonr correlation: PearsonRResult(statistic=np.float64(1.0), pvalue=np.float64(1.0))

# %%
import numpy as np
A=np.array([[2,3],[3,4],[4,2]])
B=np.array([[8,7],[9,6],[10,8]])
p=np.array([5,5])
cA=A.mean(axis=0)
cB=B.mean(axis=0)
dA=np.linalg.norm(p-cA)
dB=np.linalg.norm(p-cB)
if dA<dB:
    print("points belongs to Centroid A")
else:
    print("point belongs to Centroid B")
# Out:
# points belongs to Centroid A

# %%
import numpy as np
A=np.array([[2,3],[3,4],[4,2]])
B=np.array([[2,3],[3,4],[4,2]])
p=np.array([5,5])
cA=A.mean(axis=0)
cB=B.mean(axis=0)
dA=np.linalg.norm(p-cA)
dB=np.linalg.norm(p-cB)
if dA<dB:
    print("points belongs to Centroid A")
else:
    print("point belongs to Centroid B")
