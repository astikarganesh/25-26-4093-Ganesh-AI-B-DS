# %% [markdown]
# <a href="https://colab.research.google.com/github/astikarganesh/25-26-4093-Ganesh-AI-B-DS/blob/main/week%205_(10-03-2026)/22)z_test_hypothesis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 22)Write a code to test the hypothesis, if test for Z is accepted or rejected

# %%
import math
n=int(input("Enter the n value:"))
x=int(input("Enter the x value:") )
p_hat=x/n
SE=math.sqrt(p_hat*(1-p_hat)/n)
z=1.96
lower=p_hat-z*SE
upper=p_hat+z*SE
print("Sample proportion:",p_hat)
print("Confidence Interval:",(lower,upper))
p0=0.50
z_test=(p_hat-p0)/math.sqrt(p0*(1-p0)/n)
print("Test Statistic:",z_test)
if abs(z_test)>1.96:
    print("Reject null hypothesis")
else:
    print("Accept null hypothesis")
# Out:
# Enter the n value:6
# Enter the x value:5
# Sample proportion: 0.8333333333333334
# Confidence Interval: (0.535128829802743, 1.1315378368639237)
# Test Statistic: 1.6329931618554523
# Accept null hypothesis
